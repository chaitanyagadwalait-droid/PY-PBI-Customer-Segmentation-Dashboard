# %%
import pandas as pd
import numpy as np

df = pd.read_csv("online_retail1.csv")
df.shape

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820642 entries, 0 to 820641
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   820642 non-null  int64
#  1   Invoice      820642 non-null  object
#  2   StockCode    820642 non-null  object
#  3   Description  820642 non-null  object
#  4   Quantity     820642 non-null  int64
#  5   InvoiceDate  820642 non-null  object
#  6   Price        820642 non-null  float64
#  7   Customer ID  820642 non-null  int64
#  8   Country      820642 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 56.3+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0       Quantity          Price    Customer ID
# count  8.206420e+05  820642.000000  820642.000000  820642.000000
# mean   5.307974e+05      12.462250       2.976577   15331.157529
# std    3.083625e+05     189.371964       5.194724    1694.630797
# min    0.000000e+00  -80995.000000       0.000000   12346.000000
# 25%    2.631302e+05       2.000000       1.250000   13982.000000
# 50%    5.158235e+05       5.000000       1.950000   15270.000000
# 75%    8.068278e+05      12.000000       3.750000   16799.000000
# max    1.067369e+06   80995.000000    1100.440000   18287.000000

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.drop_duplicates()

# %%
df = df[~(df["Price"] <= 0)]

# %%
df = df[~(df["Quantity"] < 0)]

# %%
df["StockCode"] = df["StockCode"].str.upper()
df = df.drop_duplicates()

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"], format="%d-%m-%Y %H:%M")

# %%
df = df[~(df["Invoice"].str.startswith("C"))]
df.shape
# Out:
# (776577, 8)

# %%
df["Total Price"] = df["Quantity"] * df["Price"]
df.shape
# Out:
# (776577, 9)

# %%
# df.to_csv("Cleaned_online_retail.csv", index=False)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Total Price'],
#       dtype='object')

# %%
df.shape
